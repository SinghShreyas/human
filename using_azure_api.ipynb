# %% [markdown]
# # Human Data Scientist Task

# %%
import re

# Module to get the details of a research paper using doi.
from habanero import Crossref

# Module to extract text from pdf
from pdfminer.high_level import extract_text

# Azure related modules
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient

from datetime import datetime

# %%
# Exract text here.

pdf_file_path = './Azure Papers/VitD-Song.pdf'
text = extract_text(pdf_file_path, maxpages = 3)
print(text)
# Out:
# Original Article
# https://doi.org/10.9758/cpn.2020.18.2.203
# Clinical Psychopharmacology and Neuroscience 2020;18(2):203-213
#
# pISSN 1738-1088 / eISSN 2093-4327
# Copyrightⓒ 2020, Korean College of Neuropsychopharmacology
#
# Vitamin D Supplementation is Beneficial for Children with Autism
# Spectrum Disorder: A Meta-analysis
#
# Liyao  Song1,*,  Xiaomei  Luo1,*,  Qing  Jiang1,  Zhi  Chen2,  Lifang  Zhou1,  Dan  Wang1,  Ai  Chen1,3
# 1Department  of  Pediatrics,  2Nursing  Department,  The  Affiliated  Hospital  of  Southwest  Medical  University,  Luzhou,  3Department  of  Pediatric,
# Sichuan  Provincial  Hospital  for  Women  and  Children,  Chengdu,  Sichuan  Province,  China
#
# Objective: We conducted a meta-analysis of  randomized controlled  trials  to explore  whether  vitamin  D  supplementation
# is  beneficial  for  symptom  improvement  in  children  with  autism  spectrum  disorder.
# Methods:  We  systematically  searched  the  PubMed  database,  EMBASE,  Cochrane  Library,  Web  of  Science,  Sino-Med,
# Wanfang Data,  and  China  National  Knowledge  Infrastructure  mainly up  to September  2019.  Using  a fixed effects model,
# we  calculated  the  standard  mean  difference  with  95%  confidence  interval.  Furthermore,  we  analyzed  baseline  serum
# 25-hydroxyvitamin  D  levels  and  outcome  scores  including  the  Social  Responsiveness  Scale  and  Child  Autism  Rating
# Scale  scores  after  vitamin  D  supplementation.
# Results:  There  was no significant difference  in  baseline serum 25-hydroxyvitamin  D  levels  among 203 children included
# from  three studies  in the  meta-analysis. After  vitamin  D  supplementation,  the  outcome scores in  the  experimental group
# were  dramatically  elevated  compared  with  those  in  the  control  group  (p  =  0.03).
# Conclusion:  Vitamin  D  supplementation  improves  the  typical  symptoms  of  autism  spectrum  disorder,  as  indicated  by
# reduced  Social  Responsiveness  Scale and Child Autism  Rating Scale  scores; thus, it is  beneficial for  children with  autism
# spectrum  disorder.
#
# KEY  WORDS:  Vitamin  D;  Children;  Autism  spectrum  disorder;  Meta-analysis.
#
# INTRODUCTION
#
# Autism  spectrum  disorder  (ASD)  is  a  neurodevelop-
# mental disorder characterized by social, communicative,
# and behavioral deficits. Its clinical manifestations include
# indifference, communication rejection, language devel-
# opment retardation, and repeated behavioral stereotypes
# [1,2].  ASD  comprises  different  subgroups  based  on  the
# child’s primary symptoms, such as autism, Asperger’s syn-
# drome, and other unspecified generalized developmental
# disorders (Pervasive Developmental Disorder-Not Otherwise
# Specified) [1]. In the late 1990s, the prevalence of ASD
# was less than 60 per 10,000 people, and approximately
#
# Received: August 28, 2019 / Revised: October 3, 2019
# Accepted: December 2, 2019
# Address  for  correspondence: Ai Chen
# Department of Paediatrics, The Affiliated Hospital of Southwest
# Medical University, Kang-Jian Area, Kangcheng Avenue, Taiping
# Road, Jiangyang District, Luzhou, Sichuan Province 646000, China
# E-mail: zuoma78@163.com
# ORCID: https://orcid.org/0000-0003-3120-4949
# *These authors contributed equally to this study as co-first authors.
#
# 30% of the affected individuals were children [3-5]. The
# incidence of ASD has increased gradually [6,7], and the
# current prevalence is approximately 90−250 per 10,000
# individuals [8-11]. Therefore, early detection of ASD is es-
# sential for treatment and prevention.
#
# The etiology of autism remains unclear. Previous stud-
# ies  have  focused  on  genetic  factors,  brain  disease,  and
# neurobiological factors, among others. ASD is the result of
# interaction  between  genetic  and  environmental  factors
# [12]. However, hereditary factor has always been consid-
# ered to be the dominant factor [13,14]. Genetic studies
# have shown that dizygotic twins have a concordance rate
# of  approximately  31%  for  ASD.  Surprisingly,  mono-
# zygotic  twins  with  identical  DNA  only  have  a  con-
# cordance  rate  of  approximately  88%  for  ASD  [15,16].
# Furthermore, findings from twin studies suggest that the
# prenatal  environment  can  influence  the  incidence  of
# autism.  For  instance,  Godar  and  Merrill  [17]  proposed
# that low vitamin D3 levels or viral infection of the uterus
# can potentially alter the prenatal environment, leading to
#
#  This is an Open-Access article distributed under the terms of the Creative Commons Attribution Non-Commercial License (http://creativecommons.org/licenses/by-nc/4.0)
#
# which permits unrestricted non-commercial use, distribution, and reproduction in any medium, provided the original work is properly cited.
#
# 203
#
# 204 L. Song, et al.
#
# the development of ASD.
#
# Low serum vitamin D levels are a confirmed environ-
# mental risk factor for autism, not only in childhood but al-
# so during the fetal period [18,19]. Vitamin D plays an im-
# portant  role  in  the  human  nervous  system  and  is  asso-
# ciated with the prevention of depression [20-24], epilepsy
# [25-29],  schizophrenia  [30,31],  Alzheimer’s  disease
# [32,33], Parkinson’s disease [34,35], and multiple scle-
# rosis  [30,36].  The  activated  form  of  vitamin  D,  that  is,
# 1,25-dihydroxy vitamin D3 (25[OH]2D3), is a steroid with
# strong endocrine, paracrine, and autocrine effects. It par-
# ticipates in the synthesis of neurotrophic factors and en-
# zymes related to the synthesis of neurotransmitters and in
# the  inhibition  of  the  synthesis  of  inducible  nitric  oxide
# synthase;  furthermore,  it  plays  a  role  in  nourishing  the
# nerves  and  increasing  glutathione  levels.  Therefore,  it
# plays an extensive role in the brain detoxification path-
# way [36].
#
# Vitamin D binds to more than 2,700 genes and regu-
# lates  the  expression  of  more  than  200  of  these  genes
# [37-39].  It  is  necessary  for  regulating  serotonin  pro-
# duction [40]. More importantly, vitamin D increases es-
# trogen levels in the placenta and brain [41,42]. Estrogen is
# vital for brain development [43]; this may explain why
# males have a four to five times higher risk of autism than
# females [44]. Notably, patients with ASD exhibit abnor-
# mal regulation of estrogen receptor and estrogen receptor
# coactivators in the middle frontal gyrus in the brain [45].
# In addition, the combination of in vivo, in vitro, and ani-
# mal model data provides a convincing basis for the im-
# portant role of vitamin D in neuronal cell proliferation,
# differentiation,  neuroprotection,  neurotransmitter  trans-
# mission, and neuroplasticity [46,47].
#
# A decade ago, Cannell [18] first proposed a correlation
# between vitamin D and ASDs. However, few studies have
# analyzed symptom improvement in children with ASD af-
# ter vitamin D supplementation. Therefore, we performed
# a multicenter meta-analysis to provide further evidence
# on this.
#
# METHODS
#
# Search Strategy
#
# This meta-analysis evaluated the association between
# vitamin D supplementation and symptom improvement
# in  children  with  autism.  Data  were  collected  from  the
#
# PubMed  database,  EMBASE,  Cochrane  Library,  Web  of
# Science, Sino-Med, Wanfang Data, and China National
# Knowledge Infrastructure (CNKI) mainly up to September
# 2019. The search was conducted using the main termi-
# nology. Different search strategies were adopted for differ-
# ent databases. The specific search strategy is presented in
# Figures 1−3.
#
# Inclusion and Exclusion Criteria
#
# Inclusion  criteria  for  studies  collected  for  the  meta-
# analysis were as follows: (1) studies on children with ASD
# diagnosed according to the International Classification of
# Diseases (ICD-9 and ICD-10) and the Diagnostic Statistical
# Manual  of  Mental  Disorders  (DSM-4  and  DSM-5);  (2)
# studies including children aged ≤ 18 years; (3) studies in
# which specific serum vitamin D levels were directly inves-
# tigated; (4) studies reporting significant differences in vita-
# min D levels after intervention; (5) studies in which vita-
# min  D  supplementation  was  the  intervention;  and  (6)
# studies which were randomized controlled trials.
#
# Exclusion criteria were as follows: (1) studies with par-
# ticipants having any disease that could affect serum vita-
# min D levels and (2) the article type being a meta-analysis,
# observational study, review study, letter to the editor, or
# case report.
#
# Data Extraction and Quality Assessment
#
# The title, abstract, and full text  of studies  were  inde-
# pendently screened by two researchers. Unrelated studies
# were  excluded.  Specific  screening  procedures  are  de-
#
# Fig. 1. Search strategy for PubMed.
#
#  Vitamin D Supplementation and Autism Spectrum Disorder Among Children 205
#
# Fig. 2. Search strategy for Cochrane Library.
#
# Fig. 3. Search strategy for EMBASE.
#
# scribed in the “Description of studies” in the result section.
# Any disagreement between the two screening researchers
# was  resolved  through  discussion  between  them  or
# through  evaluation  by  a  third  reviewer  to  reach  a  final
# decision.  The  reasons  for  exclusion  of  articles  were
# recorded. The data collected from the relevant studies in-
# cluded the following: (1) general information: first author,
# publication  year,  research  country,  study  design,  and
# sample size; (2) specific intervention: the dose and dura-
# tion of vitamin D supplementation; (3) precise data: the
# mean and standard deviation values as well as the related
# p values of vitamin D levels and outcome scores on score
# sheet, among others. In total, three studies were included
# in this meta-analysis. The Cochrane bias test was used to
# evaluate randomized controlled trials (RCTs).
#
# Statistical Analysis
#
# The outcomes were analyzed using the Review Manager
# version 5.3 (The Nordic Cochrane Centre, The Cochrane
# Collaboration, Copenhagen, Denmark). Considering that
# data to be analyzed in this study have different units, data
# on  25(OH)  D  levels  and  Social  Responsiveness  Scale
# (SRS) and Child Autism Rating Scale (CARS) scores were
# analyzed using the standardized mean difference (SMD)
# with  95%  confidence  interval  (CI).  Statistical  hetero-
# geneity was quantified using Q test and I2 statistic. Signifi-
# cant heterogeneity was suggested as p ＜ 0.10 or I2 ＞
# 50%. If p ＞ 0.1 and/or I2 ＜ 50%, the fixed effects model
# was used to test the combined effect; otherwise, the ran-
#
# dom effects model was adopted.
#
# RESULTS
#
# Description of Studies
#
# In total, 452 studies were retrieved after searching the
# databases and other ways (contact the author or check out
# newspapers  and  magazines)  mainly  up  to  September
# 2019. Of the 452 studies, 264 were from PubMed, with
# the filter of humans; 130 from Web of Science, 19 from
# EMBASE, 17 from Cochrane Library, 6 from Wanfang da-
# ta, 14 from CNKI, and 2 from Sino-Med. Following the
# elimination of 37 duplicated articles, 33 articles were ob-
# tained by initial screening of the title and abstract. After
# browsing the full text, 29 articles (case-control study [n =
# 12], multiple research objects [n = 6], mixed intervention
# [n = 4], open-label trial [n = 4], no ending data [n = 2],
# and inappropriate inclusion criteria [n = 1]). Notably, one
# of the articles [48], both in terms of research design and fi-
# nal  analysis,  was  tremendously  consistent  with  this
# meta-analysis. However, the included children with au-
# tism had serum vitamin D levels ＜ 30 ng/ml, which was
# inconsistent  with  the  inclusion  criteria  of  the  present
# study; therefore, it was excluded. After full text screening,
# four  RCT  articles  met  the  inclusion  criteria;  however,
# among them, the article of Saad et al. [49] was retracted
# because the validity of the research results was not dem-
# onstrated [50,51]. Ultimately, three RCTs were included
# in the analysis. Figure 4 presents the selection process. In

# %%
# Regex to match doi from text
regexDOI = re.compile('[https://?doi|DOI][\s\.\:]{0,2}(10\.\d{4}[\w\:\.\-\/a-z]+)[A-Z\s]')
doi = regexDOI.findall(text)
doi
# Out:
# ['10.9758/cpn.2020.18.2.203']

# %%
# Get paper details using DOI.
cr = Crossref()

# Example uses
#cr.works(ids = '10.1176/appi.ajp.2011.10050764')
try:
    paper_id = doi[0]
    if paper_id[-1] == '.':
        paper_id = paper_id[:-1]

    paper_information = cr.works(ids = paper_id)
except:
    print("doi not found in paper")

# %%
# Extracting individual information of the paper
try:
    authors = paper_information['message']['author']
    title = paper_information['message']['title']
    published_on = paper_information['message']['published']
    paper_url = paper_information['message']['URL']
    journal_name = paper_information['message']['container-title']

    # Converting date as date-time object
    date = published_on['date-parts'][0]
    if len(date) == 3:
        yy = date[0]
        mm = date[1]
        dd = date[2]
    else:
        yy = date[0]
        mm = date[1]
        dd = 1
        
    date = datetime(yy, mm,dd)

    # Formatting author names
    all_authors = []
    for author in authors:
        full_name = author['given'] + ' ' + author['family']
        all_authors.append(full_name)
except:
    print("doi not found in paper")

# %%
# Printing all the details of the paper
try:
    print("Below is the details of the paper:")
    print("Article name: ", title[0], end = "\n\n")

    print("Authors: ", end = "")

    for author in all_authors:
        print(author, end = "")
        print(", ", end = "")
        
    print("\n\nYear: ", date.year)
    print("\nJournal Name: ", journal_name[0])
except:
    print("doi not found in paper")
# Out:
# Below is the details of the paper:
# Article name:  Vitamin D Supplementation is Beneficial for Children with Autism Spectrum Disorder: A Meta-analysis
#
# Authors: Liyao Song, Xiaomei Luo, Qing Jiang, Zhi Chen, Lifang Zhou, Dan Wang, Ai Chen,
#
# Year:  2020
#
# Journal Name:  Clinical Psychopharmacology and Neuroscience

# %%
## Preparing data to make a dataframe
try:
    articleName = []
    articleName.append(title[0])
    year_ = []
    year_.append(str(date.year))
    journal_name_ = []
    journal_name_.append(journal_name[0])

    ent_dict = {"ArticleName": articleName,"Authors": all_authors, "Year": year_, "JournalName": journal_name_ }
    ent_dict
except:
    ent_dict = {}
    print("doi not found in paper")

# %% [markdown]
# ### Azure

# %%
"""
Function to fetch named entity from Azure
Input - File path of Azure Credentials, List of texts
Output - List of entities for each documents
"""
def entity_recognition_from_azure(credentials_file_path: str, text: list) -> list:
    
    # Reading Azure credentials from a text file
    with open(credentials_file_path) as f:
        api_key, endpoint = f.readline().split(",")
        
    # Azure credentials
    credential = AzureKeyCredential(api_key)

    text_analytics_client = TextAnalyticsClient(endpoint, credential)
    
    
    poller = text_analytics_client.begin_analyze_healthcare_entities(text)
    result = poller.result()

    docs = [doc for doc in result if not doc.is_error]
    
    return docs


"""
Function to print named entity on console
Input - List of entities for each documents fetched from Azure
"""
def print_entities(docs: list):
    print("Results of Healthcare Entities Analysis:")
    for idx, doc in enumerate(docs):
        for idx1, entity in enumerate(doc.entities):
            print("Entity {}: {}".format(idx1,entity.text))
            print("...Normalized Text: {}".format(entity.normalized_text))
            print("...Category: {}".format(entity.category))
            print("...Subcategory: {}".format(entity.subcategory))
            print("...Offset: {}".format(entity.offset))
            print("...Confidence score: {}".format(entity.confidence_score))
            if entity.data_sources is not None:
                print("...Data Sources:")
                for data_source in entity.data_sources:
                    print("......Entity ID: {}".format(data_source.entity_id))
                    print("......Name: {}".format(data_source.name))
            print("\n")
            

"""
Function to print named entity on console
Input - List of entities for each documents fetched from Azure
"""
def print_relations(docs: list):
    print("Results of Healthcare Entities Analysis (Relations):")
    for idx, doc in enumerate((docs)):
        for idx1, relation in enumerate(doc.entity_relations):
            print("Relation number {}".format(idx1))                  
            print("Relation of type: {} has the following roles".format(relation.relation_type))
            for role in relation.roles:
                print("...Role '{}' with entity '{}'".format(role.name, role.entity.text))
            print("\n")

# %%
text = [text]
docss = entity_recognition_from_azure("credentials.txt", text)

# %%
print_entities(docss)
# Out:
# Results of Healthcare Entities Analysis:
# Entity 0: ;18
# ...Normalized Text: None
# ...Category: Time
# ...Subcategory: None
# ...Offset: 108
# ...Confidence score: 0.76
#
#
# Entity 1: Vitamin D Supplementation
# ...Normalized Text: Vitamin D supplementation
# ...Category: MedicationName
# ...Subcategory: None
# ...Offset: 218
# ...Confidence score: 0.6
# ...Data Sources:
# ......Entity ID: C4524013
# ......Name: UMLS
# ......Entity ID: 10079910
# ......Name: MDR
#
#
# Entity 2: Children
# ...Normalized Text: Child
# ...Category: Age
# ...Subcategory: None
# ...Offset: 262
# ...Confidence score: 0.98
# ...Data Sources:
# ......Entity ID: C0008059
# ......Name: UMLS
# ......Entity ID: 0000003204
# ......Name: AOD
# ......Entity ID: 0060058
# ......Name: CCPSS
# ......Entity ID: 0000002765
# ......Name: CHV
# ......Entity ID: 5002-0012
# ......Name: CSP
# ......Entity ID: U000730
# ......Name: DXP
# ......Entity ID: CHD
# ......Name: HL7V3.0
# ......Entity ID: U005340
# ......Name: LCH
# ......Entity ID: sh85023418
# ......Name: LCH_NW
# ......Entity ID: LA9949-4
# ......Name: LNC
# ......Entity ID: D002648
# ......Name: MSH
# ......Entity ID: C16423
# ......Name: NCI
# ......Entity ID: C16423
# ......Name: NCI_FDA
# ......Entity ID: C16423
# ......Name: NCI_NICHD
# ......Entity ID: C16423
# ......Name: NCI_caDSR
# ......Entity ID: S-10170
# ......Name: SNMI
# ......Entity ID: 67822003
# ......Name: SNOMEDCT_US
#
#
# Entity 3: Autism
# Spectrum Disorder
# ...Normalized Text: Autism Spectrum Disorders
# ...Category: Diagnosis
# ...Subcategory: None
# ...Offset: 276
# ...Confidence score: 1.0
# ...Data Sources:
# ......Entity ID: C1510586
# ......Name: UMLS
# ......Entity ID: 299.00
# ......Name: DSM-5
# ......Entity ID: HP:0000729
# ......Name: HPO
# ......Entity ID: F84.0
# ......Name: ICD10CM
# ......Entity ID: sh2008009581
# ......Name: LCH_NW
# ......Entity ID: 10063844
# ......Name: MDR
# ......Entity ID: 358515
# ......Name: MEDCIN
# ......Entity ID: 153
# ......Name: MEDLINEPLUS
# ......Entity ID: D000067877
# ......Name: MSH
# ......Entity ID: C88412
# ......Name: NCI
# ......Entity ID: C88412
# ......Name: NCI_CELLOSAURUS
# ......Entity ID: C88412
# ......Name: NCI_NICHD
# ......Entity ID: MTHU038054
# ......Name: OMIM
# ......Entity ID: 04855
# ......Name: PSY
#
#
# Entity 4: Pediatrics
# ...Normalized Text: None
# ...Category: CareEnvironment
# ...Subcategory: None
# ...Offset: 441
# ...Confidence score: 0.66
#
#
# Entity 5: Pediatric
# ...Normalized Text: None
# ...Category: CareEnvironment
# ...Subcategory: None
# ...Offset: 567
# ...Confidence score: 0.67
#
#
# Entity 6: Women
# ...Normalized Text: Woman
# ...Category: Gender
# ...Subcategory: None
# ...Offset: 615
# ...Confidence score: 1.0
# ...Data Sources:
# ......Entity ID: C0043210
# ......Name: UMLS
# ......Entity ID: 0000014451
# ......Name: AOD
# ......Entity ID: 0018392
# ......Name: CCPSS
# ......Entity ID: 0000013181
# ......Name: CHV
# ......Entity ID: U005036
# ......Name: LCH
# ......Entity ID: sh85147274
# ......Name: LCH_NW
# ......Entity ID: 4
# ......Name: MEDLINEPLUS
# ......Entity ID: D014930
# ......Name: MSH
# ......Entity ID: 23450
# ......Name: PSY
# ......Entity ID: Ua0Wg
# ......Name: RCD
# ......Entity ID: E-4957
# ......Name: SNM
# ......Entity ID: L-85B00
# ......Name: SNMI
# ......Entity ID: 224526002
# ......Name: SNOMEDCT_US
#
#
# Entity 7: Children
# ...Normalized Text: Offspring
# ...Category: FamilyRelation
# ...Subcategory: None
# ...Offset: 627
# ...Confidence score: 1.0
# ...Data Sources:
# ......Entity ID: C0680063
# ......Name: UMLS
# ......Entity ID: 0000013779
# ......Name: AOD
# ......Entity ID: 0000043202
# ......Name: CHV
# ......Entity ID: CHILD
# ...Confidence score: 0.97
# ...Data Sources:
# ......Entity ID: C0008059
# ......Name: UMLS
# ......Entity ID: 0000003204
# ......Name: AOD
# ......Entity ID: 0060058
# ......Name: CCPSS
# ......Entity ID: 0000002765
# ......Name: CHV
# ......Entity ID: 5002-0012
# ......Name: CSP
# ......Entity ID: U000730
# ......Name: DXP
# ......Entity ID: CHD
# ......Name: HL7V3.0
# ......Entity ID: U005340
# ......Name: LCH
# ......Entity ID: sh85023418
# ......Name: LCH_NW
# ......Entity ID: LA9949-4
# ......Name: LNC
# ......Entity ID: D002648
# ......Name: MSH
# ......Entity ID: C16423
# ......Name: NCI
# ......Entity ID: C16423
# ......Name: NCI_FDA
# ......Entity ID: C16423
# ......Name: NCI_NICHD
# ......Entity ID: C16423
# ......Name: NCI_caDSR
# ......Entity ID: S-10170
# ......Name: SNMI
# ......Entity ID: 67822003
# ......Name: SNOMEDCT_US
#
#
# Entity 13: autism  spectrum  disorder
# ...Normalized Text: Autism Spectrum Disorders
# ...Category: Diagnosis
# ...Subcategory: None
# ...Offset: 863
# ...Confidence score: 1.0
# ...Data Sources:
# ......Entity ID: C1510586
# ......Name: UMLS
# ......Entity ID: 299.00
# ......Name: DSM-5
# ......Entity ID: HP:0000729
# ......Name: HPO
# ......Entity ID: F84.0
# ......Name: ICD10CM
# ......Entity ID: sh2008009581
# ......Name: LCH_NW
# ......Entity ID: 10063844
# ......Name: MDR
# ......Entity ID: 358515
# ......Name: MEDCIN
# ......Entity ID: 153
# ......Name: MEDLINEPLUS
# ......Entity ID: D000067877
# ......Name: MSH
# ......Entity ID: C88412
# ......Name: NCI
# ......Entity ID: C88412
# ......Name: NCI_CELLOSAURUS
# ......Entity ID: C88412
# ......Name: NCI_NICHD
# ......Entity ID: MTHU038054
# ......Name: OMIM
# ......Entity ID: 04855
# ......Name: PSY
#
#
# Entity 14: September
# ...Normalized Text: None
# ...Category: Time
# ...Subcategory: None
# ...Offset: 1092
# ...Confidence score: 0.62
#
#
# Entity 15: serum
# 25-hydroxyvitamin  D  levels
# ...Normalized Text: None
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 1262
# ...Confidence score: 0.74
#
#
# Entity 16: Social  Responsiveness  Scale
# ...Normalized Text: None
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 1337
# ...Confidence score: 0.99
#
#
# Entity 17: Child  Autism  Rating
# Scale
# ...Normalized Text: None
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 1373
# ...Confidence score: 0.99
#
#
# Entity 18: vitamin  D
# ...Normalized Text: vitamin D
# ...Category: MedicationName
# ...Subcategory: None
# ...Offset: 1418
# ...Confidence score: 0.86
# ...Data Sources:
# ......Entity ID: C0042866
# ......Name: UMLS
# ......Entity ID: 0000018250
# ......Name: AOD
# ......Entity ID: 0000013054
# ......Name: CHV
# ......Entity ID: DB11094
# ......Name: DRUGBANK
# ......Entity ID: 1200
# ......Name: GS
# ......Entity ID: U004978
# ......Name: LCH
# ...Subcategory: None
# ...Offset: 2755
# ...Confidence score: 0.98
#
#
# Entity 58: 60
# ...Normalized Text: None
# ...Category: MeasurementValue
# ...Subcategory: None
# ...Offset: 2765
# ...Confidence score: 0.9
#
#
# Entity 59: per 10,000
# ...Normalized Text: None
# ...Category: MeasurementUnit
# ...Subcategory: None
# ...Offset: 2768
# ...Confidence score: 0.79
#
#
# Entity 60: August 28, 2019
# ...Normalized Text: None
# ...Category: Date
# ...Subcategory: None
# ...Offset: 2817
# ...Confidence score: 1.0
#
#
# Entity 61: October 3, 2019
# ...Normalized Text: None
# ...Category: Date
# ...Subcategory: None
# ...Offset: 2844
# ...Confidence score: 1.0
#
#
# Entity 62: December 2, 2019
# ...Normalized Text: None
# ...Category: Date
# ...Subcategory: None
# ...Offset: 2870
# ...Confidence score: 1.0
#
#
# Entity 63: Department of Paediatrics
# ...Normalized Text: None
# ...Category: CareEnvironment
# ...Subcategory: None
# ...Offset: 2925
# ...Confidence score: 0.93
#
#
# Entity 64: children
# ...Normalized Text: Child
# ...Category: Age
# ...Subcategory: None
# ...Offset: 3295
# ...Confidence score: 0.96
# ...Data Sources:
# ......Entity ID: C0008059
# ......Name: UMLS
# ......Entity ID: 0000003204
# ......Name: AOD
# ......Entity ID: 0060058
# ......Name: CCPSS
# ......Entity ID: 0000002765
# ......Name: CHV
# ......Entity ID: 5002-0012
# ......Name: CSP
# ......Entity ID: U000730
# ......Name: DXP
# ......Entity ID: CHD
# ......Name: HL7V3.0
# ......Entity ID: U005340
# ......Name: LCH
# ......Entity ID: sh85023418
# ......Name: LCH_NW
# ......Entity ID: LA9949-4
# ......Name: LNC
# ......Entity ID: D002648
# ......Name: MSH
# ......Entity ID: C16423
# ......Name: NCI
# ......Entity ID: C16423
# ......Name: NCI_FDA
# ......Entity ID: C16423
# ......Name: NCI_NICHD
# ......Entity ID: C16423
# ......Name: NCI_caDSR
# ......Entity ID: S-10170
# ......Name: SNMI
# ......Entity ID: 67822003
# ......Name: SNOMEDCT_US
#
#
# Entity 65: incidence
# ...Normalized Text: incidence of cases
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 3316
# ...Confidence score: 0.74
# ...Data Sources:
# ......Entity ID: C0220856
# ......Name: UMLS
# ......Entity ID: Q000453
# ......Name: MSH
#
#
# Entity 66: ASD
# ...Normalized Text: Autism Spectrum Disorders
# ...Category: Diagnosis
# ...Subcategory: None
# ...Offset: 3329
# ...Confidence score: 1.0
# ...Data Sources:
# ......Entity ID: C1510586
# ......Name: UMLS
# ......Entity ID: 299.00
# ......Name: DSM-5
# ......Entity ID: HP:0000729
# ......Name: HPO
# ......Entity ID: F84.0
# ......Name: ICD10CM
# ......Entity ID: sh2008009581
# ......Name: LCH_NW
# ......Entity ID: 10063844
# ......Name: MDR
# ......Entity ID: 358515
# ......Name: MEDCIN
# ......Entity ID: 153
# ......Name: MEDLINEPLUS
# ......Entity ID: D000067877
# ......Name: MSH
# ......Entity ID: C88412
# ......Name: NCI
# ......Entity ID: C88412
# ......Name: NCI_CELLOSAURUS
# ......Entity ID: C88412
# ......Name: NCI_NICHD
# ......Entity ID: MTHU038054
# ......Name: OMIM
# ......Entity ID: 04855
# ......Name: PSY
#
#
# Entity 67: increased gradually
# ...Normalized Text: None
# ...Category: Course
# ...Subcategory: None
# ...Offset: 3337
# ...Confidence score: 0.59
#
#
# Entity 68: prevalence
# ...Normalized Text: Statistical Prevalence
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 3381
# ...Confidence score: 0.65
# ...Data Sources:
# ......Entity ID: C0033105
# ......Name: UMLS
# ......Entity ID: 0000000454
# ......Name: AOD
# ......Entity ID: 0000010101
# ......Name: CHV
# ......Entity ID: 2383-4239
# ......Name: CSP
# ......Entity ID: D015995
# ......Name: MSH
# ......Entity ID: U003385
# ......Name: MTH
# ......Entity ID: C17010
# ......Name: NCI
#
#
# Entity 69: 90−250
# ...Normalized Text: None
# ...Category: MeasurementValue
# ...Subcategory: None
# ...Offset: 3409
# ...Confidence score: 0.96
#
#
# Entity 70: per 10,000
# ...Normalized Text: None
# ...Category: MeasurementUnit
# ...Subcategory: None
# ...Offset: 3416
# ...Confidence score: 0.88
#
#
# Entity 71: ASD
# ...Normalized Text: Autism Spectrum Disorders
# ...Category: Diagnosis
# ...Subcategory: None
# ...Offset: 3478
# ...Confidence score: 1.0
# ...Data Sources:
# ......Entity ID: C1510586
# ......Name: UMLS
# ......Entity ID: 299.00
# ......Name: DSM-5
# ......Entity ID: HP:0000729
# ......Name: HPO
# ......Entity ID: F84.0
# ......Name: ICD10CM
# ......Entity ID: sh2008009581
# ......Name: LCH_NW
# ......Entity ID: 10063844
# ......Name: MDR
# ......Entity ID: 358515
# ......Name: MEDCIN
# ......Entity ID: 153
# ......Name: MEDLINEPLUS
# ......Entity ID: D000067877
# ......Name: MSH
# ......Entity ID: C88412
# ......Name: NCI
# ......Entity ID: C88412
# ......Name: NCI_CELLOSAURUS
# ......Entity ID: C88412
# ......Name: NCI_NICHD
# ......Entity ID: MTHU038054
# ......Name: OMIM
# ......Entity ID: 04855
# ......Name: PSY
#
#
# Entity 72: treatment
# ...Normalized Text: Therapeutic procedure
# ...Category: TreatmentName
# ...Subcategory: None
# ...Offset: 3501
# ...Confidence score: 0.63
# ...Data Sources:
# ......Entity ID: C0087111
# ......Name: UMLS
# ......Entity ID: 0000002172
# ......Name: AOD
# ......Entity ID: MTHU000144
# ......Name: AOT
# ......Entity ID: 0000012162
# ......Name: CHV
# ......Entity ID: 97139
# ......Name: CPT
# ......Entity ID: 2893-9723
# ......Name: CSP
# ......Entity ID: 97139
# ......Name: HCPT
# ......Entity ID: 0373
# ......Name: HL7V2.5
# ......Entity ID: therapy
# ......Name: HL7V3.0
# ......Entity ID: MTHU074002
# ......Name: ICPC2ICD10ENG
# ......Entity ID: A59001
# ......Name: ICPC2P
# ......Entity ID: U004645
# ......Name: LCH
# ......Entity ID: sh85134723
# ......Name: LCH_NW
# ......Entity ID: LP267221-2
# ......Entity ID: D000067877
# ......Name: MSH
# ......Entity ID: C88412
# ......Name: NCI
# ......Entity ID: C88412
# ......Name: NCI_CELLOSAURUS
# ......Entity ID: C88412
# ......Name: NCI_NICHD
# ......Entity ID: MTHU038054
# ......Name: OMIM
# ......Entity ID: 04855
# ......Name: PSY
#
#
# Entity 77: dizygotic twins
# ...Normalized Text: Twins, Dizygotic (person)
# ...Category: FamilyRelation
# ...Subcategory: None
# ...Offset: 3899
# ...Confidence score: 1.0
# ...Data Sources:
# ......Entity ID: C0041429
# ......Name: UMLS
# ......Entity ID: 0000027183
# ......Name: AOD
# ......Entity ID: 0000012675
# ......Name: CHV
# ......Entity ID: 4000-0168
# ......Name: CSP
# ......Entity ID: FTWIN
# ......Name: HL7V3.0
# ......Entity ID: D014429
# ......Name: MSH
# ......Entity ID: C73428
# ......Name: NCI
# ......Entity ID: C73428
# ......Name: NCI_CDISC
# ......Entity ID: C73428
# ......Name: NCI_GDC
# ......Entity ID: C73428
# ......Name: NCI_caDSR
# ......Entity ID: 22850
# ......Name: PSY
# ......Entity ID: XE1SL
# ......Name: RCD
# ......Entity ID: F-35620
# ......Name: SNM
# ......Entity ID: S-10149
# ......Name: SNMI
# ......Entity ID: 313416000
# ......Name: SNOMEDCT_US
#
#
# Entity 78: concordance rate
# ...Normalized Text: None
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 3922
# ...Confidence score: 0.99
#
#
# Entity 79: 31
# ...Normalized Text: None
# ...Category: MeasurementValue
# ...Subcategory: None
# ...Offset: 3959
# ...Confidence score: 0.96
#
#
# Entity 80: %
# ...Normalized Text: None
# ...Category: MeasurementUnit
# ...Subcategory: None
# ...Offset: 3961
# ...Confidence score: 1.0
#
#
# Entity 81: ASD
# ...Normalized Text: Autism Spectrum Disorders
# ...Category: Diagnosis
# ...Subcategory: None
# ...Offset: 3969
# ...Confidence score: 1.0
# ...Data Sources:
# ......Entity ID: C1510586
# ......Name: UMLS
# ......Entity ID: 299.00
# ......Name: DSM-5
# ......Entity ID: HP:0000729
# ......Name: HPO
# ......Entity ID: F84.0
# ......Name: ICD10CM
# ......Entity ID: sh2008009581
# ......Name: LCH_NW
# ......Entity ID: 10063844
# ......Name: MDR
# ......Entity ID: 358515
# ......Name: MEDCIN
# ......Entity ID: 153
# ......Name: MEDLINEPLUS
# ......Entity ID: D000067877
# ......Name: MSH
# ......Entity ID: C88412
# ......Name: NCI
# ......Entity ID: C88412
# ......Name: NCI_CELLOSAURUS
# ......Entity ID: C88412
# ......Name: NCI_NICHD
# ......Entity ID: MTHU038054
# ......Name: OMIM
# ......Entity ID: 04855
# ......Name: PSY
#
#
# Entity 82: mono-
# zygotic  twins
# ...Normalized Text: None
# ...Category: FamilyRelation
# ...Subcategory: None
# ...Offset: 3990
# ...Confidence score: 0.98
#
#
# Entity 83: DNA
# ...Normalized Text: None
# ...Category: GeneOrProtein
# ...Subcategory: None
# ...Offset: 4029
# ...Confidence score: 0.99
#
#
# Entity 84: con-
# ......Entity ID: MTHU004240
# ......Name: OMIM
# ......Entity ID: 04850
# ......Name: PSY
# ......Entity ID: XE2v2
# ......Name: RCD
# ......Entity ID: F-91640
# ......Name: SNM
# ......Entity ID: D9-18110
# ......Name: SNMI
# ......Entity ID: 408856003
# ......Name: SNOMEDCT_US
# ...
# ......Name: NCI_caDSR
# ......Entity ID: S-10170
# ......Name: SNMI
# ......Entity ID: 67822003
# ......Name: SNOMEDCT_US
#
#
# Entity 172: ≤
# ...Normalized Text: None
# ...Category: RelationalOperator
# ...Subcategory: None
# ...Offset: 7820
# ...Confidence score: 1.0
#
#
# Entity 173: 18 years
# ...Normalized Text: None
# ...Category: Age
# ...Subcategory: None
# ...Offset: 7822
# ...Confidence score: 1.0
#
#
# Entity 174: serum vitamin D levels
# ...Normalized Text: Serum vitamin D measurement
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 7863
# ...Confidence score: 0.94
# ...Data Sources:
# ......Entity ID: C0428586
# ......Name: UMLS
# ......Entity ID: 0038U
# ......Name: CPT
# ......Entity ID: 0038U
# ......Name: HCPT
# ......Entity ID: 81266
# ......Name: MEDCIN
# ......Entity ID: 270990000
# ......Name: SNOMEDCT_US
#
#
# Entity 175: min
# ...Normalized Text: Minute Unit of Plane Angle
# ...Category: MedicationName
# ...Subcategory: None
# ...Offset: 7971
# ...Confidence score: 0.71
# ...Data Sources:
# ......Entity ID: C2347166
# ......Name: UMLS
# ......Entity ID: C68860
# ......Name: NCI
# ......Entity ID: 12879
# ......Name: NCI_NCI-HL7
# ......Entity ID: 1156209001
# ......Name: SNOMEDCT_US
#
#
# Entity 176: D levels
# ...Normalized Text: None
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 7975
# ...Confidence score: 0.61
#
#
# Entity 177: intervention
# ...Normalized Text: Interventional procedure
# ...Category: TreatmentName
# ...Subcategory: None
# ...Offset: 7990
# ...Confidence score: 0.69
# ...Data Sources:
# ......Entity ID: C0184661
# ......Name: UMLS
# ......Entity ID: 0039176
# ......Name: CCPSS
# ......Entity ID: MTHU000002
# ......Name: CCS
# ......Entity ID: 0000058032
# ......Name: CHV
# ......Entity ID: 4000-0348
# ......Name: CSP
# ......Entity ID: 00-99.99
# ......Name: ICD9CM
# ......Entity ID: LP73191-6
# ......Name: LNC
# ......Entity ID: 10075978
# ......Name: MDR
# ......Entity ID: D008722
# ......Name: MSH
# ......Entity ID: C25218
# ......Name: NCI
# ......Entity ID: C25218
# ......Name: NCI_BRIDG_3_0_3
# ......Entity ID: C25218
# ......Name: NCI_BRIDG_5_3
# ......Entity ID: C25218
# ......Name: NCI_CDISC-GLOSS
# ......Entity ID: CDR0000454757
# ......Name: NCI_NCI-GLOSS
# ......Entity ID: C25218
# ......Name: NCI_NICHD
# ......Entity ID: CDR0000256087
# ......Name: PDQ
# ......Entity ID: P-0010
# ......Name: SNM
# ......Entity ID: P0-00000
# ......Name: SNMI
# ......Entity ID: 71388002
# ......Name: SNOMEDCT_US
#
#
# Entity 178: vita-
# min  D
# ...Normalized Text: None
# ...Category: MedicationName
# ...Subcategory: None
# ...Offset: 8025
# ...Confidence score: 0.93
#
#
# Entity 179: randomized controlled trials
# ...Normalized Text: None
# ...Category: AdministrativeEvent
# ...Subcategory: None
# ...Offset: 8110
# ...Confidence score: 0.78
#
#
# Entity 180: par-
# ticipants
# ...Normalized Text: None
# ...Category: Diagnosis
# ...Subcategory: None
# ...Offset: 8194
# ...Confidence score: 0.83
#
#
# Entity 181: disease
# ...Normalized Text: Disease
# ...Category: Diagnosis
# ...Subcategory: None
# ...Offset: 8220
# ...Confidence score: 0.99
# ...Data Sources:
# ......Entity ID: C0012634
# ......Name: UMLS
# ......Entity ID: 0007490
# ......Name: CCPSS
# ......Entity ID: 0000004014
# ......Name: CHV
# ......Entity ID: 0944-4756
# ......Name: CSP
# ......Entity ID: MTHU000256
# ......Name: ICPC2ICD10ENG
# ......Entity ID: A99001
# ......Name: ICPC2P
# ......Entity ID: U001423
# ......Name: LCH
# ......Entity ID: sh85038411
# ......Name: LCH_NW
# ......Entity ID: LP21006-9
# ......Name: LNC
# ......Entity ID: 39448
# ......Name: MEDCIN
# ......Entity ID: D004194
# ......Name: MSH
# ......Entity ID: C2991
# ......Name: NCI
# ......Entity ID: C2991
# ......Name: NCI_CDISC-GLOSS
# ......Entity ID: C2991
# ......Name: NCI_CTDC
# ......Entity ID: C2991
# ......Name: NCI_CTRP
# ......Entity ID: CDR0000651193
# ......Name: NCI_NCI-GLOSS
# ......Entity ID: C2991
# ......Name: NCI_NICHD
# ......Entity ID: C2991
# ......Name: NCI_caDSR
# ......Entity ID: 14520
# ......Name: PSY
# ......Entity ID: X0003
# ......Name: RCD
# ......Entity ID: D-Y000
# ......Name: SNM
# ......Entity ID: DF-00000
# ......Name: SNMI
# ......Entity ID: 64572001
# ......Name: SNOMEDCT_US
#
#
# Entity 182: serum vita-
# min D levels
# ...Normalized Text: None
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 8246
# ...Confidence score: 0.91
#
#
# Entity 183: meta-analysis
# ...Normalized Text: None
# ...Category: AdministrativeEvent
# ...Subcategory: None
# ...Offset: 8304
# ...Confidence score: 0.74
#
#
# Entity 184: observational study
# ...Normalized Text: None
# ...Category: AdministrativeEvent
# ...Subcategory: None
# ...Offset: 8320
# ...Confidence score: 0.79
#
#
# Entity 185: review study
# ...Normalized Text: None
# ...Category: AdministrativeEvent
# ...Subcategory: None
# ...Offset: 8341
# ...Confidence score: 0.69
#
#
# Entity 186: Vitamin D
# ...Normalized Text: vitamin D
# ...Category: MedicationName
# ...Subcategory: None
# ...Offset: 8652
# ...Confidence score: 0.97
# ...Data Sources:
# ......Entity ID: C0042866
# ......Name: UMLS
# ......Entity ID: 0000018250
# ......Name: AOD
# ......Entity ID: 0000013054
# ......Name: CHV
# ......Entity ID: DB11094
# ......Name: DRUGBANK
# ......Entity ID: 1200
# ......Name: GS
# ......Entity ID: U004978
# ......Name: LCH
# ......Entity ID: sh85143982
# ......Entity ID: 1200
# ......Name: GS
# ......Entity ID: U004978
# ......Name: LCH
# ......Entity ID: sh85143982
# ......Name: LCH_NW
# ......Entity ID: 41301
# ......Name: MEDCIN
# ......Entity ID: 5383
# ......Name: MEDLINEPLUS
# ......Entity ID: 5688
# ......Name: MMSL
# ......Entity ID: D014807
# ......Name: MSH
# ......Entity ID: U000310
# ......Name: MTH
# ......Entity ID: 9VU1KI44GP
# ......Name: MTHSPL
# ......Entity ID: Ub09R
# ......Name: RCD
# ......Entity ID: 11253
# ......Name: RXNORM
# ......Entity ID: F-16070
# ......Name: SNM
# ......Entity ID: F-BB070
# ......Name: SNMI
# ......Entity ID: 30178006
# ......Name: SNOMEDCT_US
# ......Entity ID: 4017649
# ......Name: VANDF
#
#
# Entity 190: vitamin D levels
# ...Normalized Text: None
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 9483
# ...Confidence score: 0.98
#
#
# Entity 191: meta-analysis
# ...Normalized Text: None
# ...Category: AdministrativeEvent
# ...Subcategory: None
# ...Offset: 9597
# ...Confidence score: 0.74
#
#
# Entity 192: test
# ...Normalized Text: Laboratory Procedures
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 9630
# ...Confidence score: 0.83
# ...Data Sources:
# ......Entity ID: C0022885
# ......Name: UMLS
# ......Entity ID: 0000026780
# ......Name: AOD
# ......Entity ID: 0000007165
# ......Name: CHV
# ......Entity ID: 92
# ......Name: CPM
# ......Entity ID: Level 2: Q0111-Q0115
# ......Name: HCPCS
# ......Entity ID: MTHU073828
# ......Name: ICPC2ICD10ENG
# ......Entity ID: 10059938
# ......Name: MDR
# ......Entity ID: 210
# ......Name: MEDLINEPLUS
# ......Entity ID: C25294
# ......Name: NCI
# ......Entity ID: C25294
# ......Name: NCI_CTRP
# ......Entity ID: CDR0000046590
# ......Name: NCI_NCI-GLOSS
# ......Entity ID: C25294
# ......Name: NCI_NICHD
# ......Entity ID: C25294
# ......Name: NCI_caDSR
# ......Entity ID: 184015
# ......Name: NOC
# ......Entity ID: CDR0000549865
# ......Name: PDQ
# ......Entity ID: X7A0B
# ......Name: RCD
# ......Entity ID: P-2000
# ......Name: SNM
# ......Entity ID: P3-00030
# ......Name: SNMI
# ......Entity ID: 108252007
# ......Name: SNOMEDCT_US
#
#
# Entity 193: 25(OH)  D  levels
# ...Normalized Text: None
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 9946
# ...Confidence score: 0.94
#
#
# Entity 194: Social  Responsiveness  Scale
# ...Normalized Text: None
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 9970
# ...Confidence score: 0.94
#
#
# Entity 195: SRS
# ...Normalized Text: Radiolabeled somatostatin analog study
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 10002
# ...Confidence score: 0.99
# ...Data Sources:
# ......Entity ID: C0473935
# ......Name: UMLS
# ......Entity ID: 103784
# ......Name: MEDCIN
# ......Entity ID: C93342
# ......Name: NCI
# ......Entity ID: CDR0000390253
# ......Name: NCI_NCI-GLOSS
# ......Entity ID: X70km
# ......Name: RCD
# ......Entity ID: X70km
# ......Name: RCDAE
# ......Entity ID: 764277001
# ......Name: SNOMEDCT_US
#
#
# Entity 196: Child Autism Rating Scale
# ...Normalized Text: None
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 10011
# ...Confidence score: 0.99
#
#
# Entity 197: CARS
# ...Normalized Text: Coherent Anti-Stokes Raman Spectroscopy
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 10038
# ...Confidence score: 0.99
# ...Data Sources:
# ......Entity ID: C5202635
# ......Name: UMLS
# ......Entity ID: C160771
# ......Name: NCI
# ......Entity ID: C160771
# ......Name: NCI_CTRP
#
#
# Entity 198: standardized mean difference
# ...Normalized Text: None
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 10076
# ...Confidence score: 0.72
#
#
# Entity 199: SMD
# ...Normalized Text: Simo Decoction
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 10106
# ...Confidence score: 0.72
# ...Data Sources:
# ......Entity ID: C4050515
# ......Name: UMLS
# ......Entity ID: C122395
# ......Name: NCI
# ......Entity ID: CDR0000772343
# ......Name: PDQ
#
#
# Entity 200: 95
# ...Normalized Text: None
# ...Category: MeasurementValue
# ...Subcategory: None
# ...Offset: 10118
# ...Confidence score: 0.99
#
#
# Entity 201: %
# ...Normalized Text: None
# ...Category: MeasurementUnit
# ...Subcategory: None
# ...Offset: 10120
# ...Confidence score: 0.99
#
#
# Entity 202: ＜
# ...Normalized Text: None
# ...Category: RelationalOperator
# ...Subcategory: None
# ...Offset: 10274
# ...Confidence score: 0.79
#
#
# Entity 203: ＞
# ...Normalized Text: None
# ...Category: RelationalOperator
# ...Subcategory: None
# ...Offset: 10287
# ...Confidence score: 0.98
#
#
# Entity 204: 50
# ...Normalized Text: None
# ...Category: MeasurementValue
# ...Subcategory: None
# ...Offset: 10290
# ...Confidence score: 0.9
#
#
# Entity 205: %
# ...Normalized Text: None
# ...Category: MeasurementUnit
# ...Subcategory: None
# ...Offset: 10292
# ...Confidence score: 0.9
#
#
# Entity 206: ＞
# ...Normalized Text: None
# ...Category: RelationalOperator
# ...Subcategory: None
# ...Offset: 10300
# ...Confidence score: 0.99
#
#
# Entity 207: 0.1
# ...Normalized Text: None
# ...Category: MeasurementValue
# ...Subcategory: None
# ...Offset: 10302
# ...Confidence score: 0.67
#
#
# Entity 208: ＜
# ...Normalized Text: None
# ...Category: RelationalOperator
# ...Subcategory: None
# ...Offset: 10316
# ...Confidence score: 0.99
#
#
# Entity 209: 50
# ...Normalized Text: None
# ...Category: MeasurementValue
# ...Subcategory: None
# ...Offset: 10318
# ...Confidence score: 0.9
#
#
# Entity 210: %
# ...Normalized Text: None
# ...Category: MeasurementUnit
# ...Subcategory: None
# ...Offset: 10320
# ...Confidence score: 0.99
#
#
# Entity 211: model
# ...Normalized Text: Model
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 10419
# ...Confidence score: 0.61
# ...Data Sources:
# ......Entity ID: C3161035
# ......Name: UMLS
# ......Entity ID: C16866
# ......Name: NCI
# ......Entity ID: C16866
# ......Name: NCI_CDISC-GLOSS
#
#
# Entity 212: September
# ...Normalized Text: None
# ...Category: Time
# ...Subcategory: None
# ...Offset: 10635
# ...Confidence score: 0.93
#
#
# Entity 213: studies
# ...Normalized Text: None
# ...Category: AdministrativeEvent
# ...Subcategory: None
# ...Offset: 10663
# ...Confidence score: 0.76
#
#
# Entity 214: case-control study
# ...Normalized Text: None
# ...Category: AdministrativeEvent
# ...Subcategory: None
# ...Offset: 11022
# ...Confidence score: 0.79
#
#
# Entity 215: open-label
# ...Normalized Text: None
# ...Category: AdministrativeEvent
# ...Subcategory: None
# ...Offset: 11116
# ...Confidence score: 0.62
#
#
# Entity 216: fi-
# nal  analysis
# ...Normalized Text: None
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 11287
# ...Confidence score: 0.91
#
#
# Entity 217: meta-analysis
# ...Normalized Text: Meta-Analysis (publications)
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 11350
# ...Confidence score: 0.76
# ...Data Sources:
# ......Entity ID: C0282458
# ......Name: UMLS
# ......Entity ID: 0000027599
# ......Name: CHV
# ......Entity ID: sh85084006
# ......Name: LCH_NW
# ......Entity ID: D017418
# ......Name: MSH
#
#
# Entity 218: children
# ...Normalized Text: Child
# ...Category: Age
# ...Subcategory: None
# ...Offset: 11387
# ...Confidence score: 0.98
# ...Data Sources:
# ......Entity ID: C0008059
# ......Name: UMLS
# ......Entity ID: 0000003204
# ......Name: AOD
# ......Entity ID: 0060058
# ......Name: CCPSS
# ......Entity ID: 0000002765
# ......Name: CHV
# ......Entity ID: 5002-0012
# ......Name: CSP
# ......Entity ID: U000730
# ......Name: DXP
# ......Entity ID: CHD
# ......Name: HL7V3.0
# ......Entity ID: U005340
# ......Name: LCH
# ......Entity ID: sh85023418
# ......Name: LCH_NW
# ......Entity ID: LA9949-4
# ......Name: LNC
# ......Entity ID: D002648
# ......Name: MSH
# ......Entity ID: C16423
# ......Name: NCI
# ......Entity ID: C16423
# ......Name: NCI_FDA
# ......Entity ID: C16423
# ......Name: NCI_NICHD
# ......Entity ID: C16423
# ......Name: NCI_caDSR
# ......Entity ID: S-10170
# ......Name: SNMI
# ......Entity ID: 67822003
# ......Name: SNOMEDCT_US
#
#
# Entity 219: serum vitamin D levels
# ...Normalized Text: Serum vitamin D measurement
# ...Category: ExaminationName
# ...Subcategory: None
# ...Offset: 11414
# ...Confidence score: 0.99
# ...Data Sources:
# ......Entity ID: C0428586
# ......Name: UMLS
# ......Entity ID: 0038U
# ......Name: CPT
# ......Entity ID: 0038U
# ......Name: HCPT
# ......Entity ID: 81266
# ......Name: MEDCIN
# ......Entity ID: 270990000
# ......Name: SNOMEDCT_US
#
#
# Entity 220: ＜
# ...Normalized Text: None
# ...Category: RelationalOperator
# ...Subcategory: None
# ...Offset: 11437
# ...Confidence score: 1.0
#
#
# Entity 221: 30
# ...Normalized Text: None
# ...Category: MeasurementValue
# ...Subcategory: None
# ...Offset: 11439
# ...Confidence score: 1.0
#
#
# Entity 222: ng/ml
# ...Normalized Text: None
# ...Category: MeasurementUnit
# ...Subcategory: None
# ...Offset: 11442
# ...Confidence score: 1.0
#
#
# Entity 223: RCT
# ...Normalized Text: None
# ...Category: AdministrativeEvent
# ...Subcategory: None
# ...Offset: 11593
# ...Confidence score: 0.71

# %%
print_relations(docss)
# Out:
# Results of Healthcare Entities Analysis (Relations):
# Relation number 0
# Relation of type: CourseOfCondition has the following roles
# ...Role 'Condition' with entity 'symptom'
# ...Role 'Course' with entity 'improvement'
#
#
# Relation number 1
# Relation of type: CourseOfCondition has the following roles
# ...Role 'Course' with entity 'improves'
# ...Role 'Condition' with entity 'symptoms'
#
#
# Relation number 2
# Relation of type: CourseOfCondition has the following roles
# ...Role 'Course' with entity 'improves'
# ...Role 'Condition' with entity 'autism  spectrum  disorder'
#
#
# Relation number 3
# Relation of type: ValueOfExamination has the following roles
# ...Role 'Value' with entity 'reduced'
# ...Role 'Examination' with entity 'Social  Responsiveness  Scale'
#
#
# Relation number 4
# Relation of type: ValueOfExamination has the following roles
# ...Role 'Value' with entity 'reduced'
# ...Role 'Examination' with entity 'Child Autism  Rating Scale'
#
#
# Relation number 5
# Relation of type: Abbreviation has the following roles
# ...Role 'FullTerm' with entity 'Autism  spectrum  disorder'
# ...Role 'AbbreviatedTerm' with entity 'ASD'
#
#
# Relation number 6
# Relation of type: Abbreviation has the following roles
# ...Role 'FullTerm' with entity 'Autism  spectrum  disorder'
# ...Role 'AbbreviatedTerm' with entity 'ASD'
#
#
# Relation number 7
# Relation of type: Abbreviation has the following roles
# ...Role 'FullTerm' with entity 'Autism  spectrum  disorder'
# ...Role 'AbbreviatedTerm' with entity 'ASD'
#
#
# Relation number 8
# Relation of type: Abbreviation has the following roles
# ...Role 'FullTerm' with entity 'Autism  spectrum  disorder'
# ...Role 'AbbreviatedTerm' with entity 'ASD'
#
#
# Relation number 9
# Relation of type: Abbreviation has the following roles
# ...Role 'FullTerm' with entity 'Autism  spectrum  disorder'
# ...Role 'AbbreviatedTerm' with entity 'ASD'
#
#
# Relation number 10
# Relation of type: Abbreviation has the following roles
# ...Role 'FullTerm' with entity 'Autism  spectrum  disorder'
# ...Role 'AbbreviatedTerm' with entity 'ASD'
#
#
# Relation number 11
# Relation of type: Abbreviation has the following roles
# ...Role 'FullTerm' with entity 'Autism  spectrum  disorder'
# ...Role 'AbbreviatedTerm' with entity 'ASD'
#
#
# Relation number 12
# Relation of type: Abbreviation has the following roles
# ...Role 'FullTerm' with entity 'Autism  spectrum  disorder'
# ...Role 'AbbreviatedTerm' with entity 'ASD'
#
#
# Relation number 13
# Relation of type: Abbreviation has the following roles
# ...Role 'FullTerm' with entity 'Autism  spectrum  disorder'
# ...Role 'AbbreviatedTerm' with entity 'ASD'
#
#
# Relation number 14
# Relation of type: CourseOfCondition has the following roles
# ...Role 'Course' with entity 'repeated'
# ...Role 'Condition' with entity 'behavioral stereotypes'
#
#
# Relation number 15
# Relation of type: QualifierOfCondition has the following roles
# ...Role 'Qualifier' with entity 'unspecified'
# ...Role 'Condition' with entity 'developmental
# disorders'
#
#
# Relation number 16
# Relation of type: TimeOfCondition has the following roles
# ...Role 'Time' with entity 'late 1990s'
# ...Role 'Condition' with entity 'ASD'
#
#
# Relation number 17
# Relation of type: CourseOfCondition has the following roles
# ...Role 'Condition' with entity 'ASD'
# ...Role 'Course' with entity 'increased gradually'
#
#
# Relation number 18
# Relation of type: ValueOfExamination has the following roles
# ...Role 'Examination' with entity 'prevalence'
# ...Role 'Value' with entity '90−250'
#
#
# Relation number 19
# Relation of type: UnitOfExamination has the following roles
# ...Role 'Examination' with entity 'prevalence'
# ...Role 'Unit' with entity 'per 10,000'
#
#
# Relation number 20
# Relation of type: ValueOfExamination has the following roles
# ...Role 'Examination' with entity 'concordance rate'
# ...Role 'Value' with entity '31'
#
#
# Relation number 21
# Relation of type: UnitOfExamination has the following roles
# ...Role 'Examination' with entity 'concordance rate'
# ...Role 'Unit' with entity '%'
#
#
# Relation number 22
# Relation of type: ValueOfExamination has the following roles
# ...Role 'Examination' with entity 'con-
# cordance  rate'
# ...Role 'Value' with entity '88'
#
#
# Relation number 23
# Relation of type: UnitOfExamination has the following roles
# ...Role 'Examination' with entity 'con-
# cordance  rate'
# ...Role 'Unit' with entity '%'
#
#
# Relation number 24
# Relation of type: ValueOfExamination has the following roles
# ...Role 'Value' with entity 'low'
# ...Role 'Examination' with entity 'vitamin D3 levels'
#
#
# Relation number 25
# Relation of type: BodySiteOfCondition has the following roles
# ...Role 'Condition' with entity 'viral infection'
# ...Role 'BodyStructure' with entity 'uterus'
#
#
# Relation number 26
# Relation of type: ValueOfExamination has the following roles
# ...Role 'Value' with entity 'Low'
# ...Role 'Examination' with entity 'serum vitamin D levels'
#
#
# Relation number 27
# Relation of type: BodySiteOfTreatment has the following roles
# ...Role 'BodyStructure' with entity 'nervous  system'
# ...Role 'Treatment' with entity 'prevention'
#
#
# Relation number 28
# Relation of type: ExpressionOfGene has the following roles
# ...Role 'Gene' with entity 'genes'
# ...Role 'Expression' with entity 'expression'
#
#
# Relation number 29
# Relation of type: BodySiteOfCondition has the following roles
# ...Role 'BodyStructure' with entity 'brain'
# ...Role 'Condition' with entity 'autism'
#
#
# Relation number 30
# Relation of type: BodySiteOfCondition has the following roles
# ...Role 'Condition' with entity 'ASD'
# ...Role 'BodyStructure' with entity 'middle frontal gyrus'
#
#
# Relation number 31
# Relation of type: BodySiteOfCondition has the following roles
# ...Role 'Condition' with entity 'ASD'
# ...Role 'BodyStructure' with entity 'brain'
#
#
# Relation number 32
# Relation of type: MutationTypeOfGene has the following roles
# ...Role 'MutationType' with entity 'abnor-
# mal'
# ...Role 'Gene' with entity 'estrogen receptor'
#
#
# Relation number 33
# Relation of type: MutationTypeOfGene has the following roles
# ...Role 'MutationType' with entity 'abnor-
# mal'
# ...Role 'Gene' with entity 'estrogen receptor
# coactivators'
#
#
# Relation number 34
# Relation of type: CourseOfCondition has the following roles
# ...Role 'Condition' with entity 'symptom'
# ...Role 'Course' with entity 'improvement'
#
#
# Relation number 35
# Relation of type: CourseOfCondition has the following roles
# ...Role 'Condition' with entity 'symptom'
# ...Role 'Course' with entity 'improvement'
#
#
# Relation number 36
# Relation of type: ExaminationFindsCondition has the following roles
# ...Role 'Condition' with entity 'ASD'
# ...Role 'Examination' with entity 'International Classification of
# Diseases'
#
#
# Relation number 37
# Relation of type: ExaminationFindsCondition has the following roles
# ...Role 'Condition' with entity 'ASD'
# ...Role 'Examination' with entity 'ICD-10'
#
#
# Relation number 38
# Relation of type: Abbreviation has the following roles
# ...Role 'FullTerm' with entity 'Child Autism Rating Scale'
# ...Role 'AbbreviatedTerm' with entity 'CARS'
#
#
# Relation number 39
# Relation of type: Abbreviation has the following roles
# ...Role 'FullTerm' with entity 'standardized mean difference'
# ...Role 'AbbreviatedTerm' with entity 'SMD'
#
#
# Relation number 40
# Relation of type: ValueOfExamination has the following roles
# ...Role 'Examination' with entity 'standardized mean difference'
# ...Role 'Value' with entity '95'
#
#
# Relation number 41
# Relation of type: UnitOfExamination has the following roles
# ...Role 'Examination' with entity 'standardized mean difference'
# ...Role 'Unit' with entity '%'
#
#
# Relation number 42
# Relation of type: ValueOfExamination has the following roles
# ...Role 'Examination' with entity 'SMD'
# ...Role 'Value' with entity '95'
#
#
# Relation number 43
# Relation of type: UnitOfExamination has the following roles
# ...Role 'Examination' with entity 'SMD'
# ...Role 'Unit' with entity '%'
#
#
# Relation number 44
# Relation of type: RelationOfExamination has the following roles
# ...Role 'Examination' with entity 'serum vitamin D levels'
# ...Role 'Relation' with entity '＜'
#
#
# Relation number 45
# Relation of type: ValueOfExamination has the following roles
# ...Role 'Examination' with entity 'serum vitamin D levels'
# ...Role 'Value' with entity '30'
#
#
# Relation number 46
# Relation of type: UnitOfExamination has the following roles
# ...Role 'Examination' with entity 'serum vitamin D levels'
# ...Role 'Unit' with entity 'ng/ml'

# %%
age_entity = []
for idx, doc in enumerate(docss):
    for idx1, entity in enumerate(doc.entities):
        if entity.category == "Age":
            text_ = entity.text
            offset = entity.offset
            
            age_entity.append([text_, offset])

# %%
age_entity
# Out:
# [['Children', 262],
#  ['children', 847],
#  ['children', 1554],
#  ['children', 2031],
#  ['Children', 2101],
#  ['children', 3295],
#  ['childhood', 4871],
#  ['fetal', 4903],
#  ['children', 6758],
#  ['children', 7038],
#  ['children', 7591],
#  ['children', 7806],
#  ['18 years', 7822],
#  ['Children', 8713],
#  ['children', 11387]]

# %%
actual_snippet = []
for ent,offset in age_entity:
    actual_snippet.append([ent, text[0][offset - 15:offset + 25]])

# %%
actual_snippet
# Out:
# [['Children', 'Beneficial for Children with Autism \nSpe'],
#  ['children', 'provement  in  children  with  autism  s'],
#  ['children', 'els  among 203 children included \nfrom  '],
#  ['children', 'eneficial for  children with  autism \nsp'],
#  ['Children', '  Vitamin  D;  Children;  Autism  spectr'],
#  ['children', 'dividuals were children [3-5]. The \ninci'],
#  ['childhood', 'm, not only in childhood but al-\nso duri'],
#  ['fetal', '\nso during the fetal period [18,19]. Vit'],
#  ['children', 'improvement in children with ASD af-\nter'],
#  ['children', 'provement \nin  children  with  autism.  '],
#  ['children', '(1) studies on children with ASD \ndiagno'],
#  ['children', 'dies including children aged ≤ 18 years;'],
#  ['18 years', 'hildren aged ≤ 18 years; (3) studies in '],
#  ['Children', 'Disorder Among Children 205\n\nFig. 2. Sea'],
#  ['children', ', the included children with au-\ntism ha']]

# %%
for idx, doc in enumerate(docss):
    for idx1, entity in enumerate(doc.entities):
        cat = entity.category
        text_str = entity.text
        if cat not in ent_dict.keys():
            ent_dict[cat] = [text_str]
        else:
            previous_text = ent_dict[cat]
            previous_text.append(text_str)
            ent_dict[cat] = previous_text

# %%
for key in ent_dict.keys():
    temp = ent_dict[key]
    temp = set(temp)
    ent_dict[key] = temp

# %%
ent_dict
# Out:
# {'ArticleName': {'Vitamin D Supplementation is Beneficial for Children with Autism Spectrum Disorder: A Meta-analysis'},
#  'Authors': {'Ai Chen',
#   'Dan Wang',
#   'Lifang Zhou',
#   'Liyao Song',
#   'Qing Jiang',
#   'Xiaomei Luo',
#   'Zhi Chen'},
#  'Year': {'2020'},
#  'JournalName': {'Clinical Psychopharmacology and Neuroscience'},
#  'Time': {'30,36', ';18', 'September', 'ago', 'late 1990s'},
#  'MedicationName': {'1,25-dihydroxy vitamin D3',
#   'D',
#   'Vitamin  D',
#   'Vitamin D',
#   'Vitamin D Supplementation',
#   'min',
#   'vita-\nmin  D',
#   'vitamin',
#   'vitamin  D',
#   'vitamin D'},
#  'Age': {'18 years', 'Children', 'childhood', 'children', 'fetal'},
#  'Diagnosis': {'ASD',
#   'ASDs',
#   'Alzheimer’s  disease',
#   'Asperger’s syn-\ndrome',
#   'Autism \nSpectrum Disorder',
#   'Autism  spectrum  disorder',
#   'Autism Spectrum Disorder',
#   'Parkinson’s disease',
#   'Pervasive Developmental Disorder',
#   'af',
#   'autism',
#   'autism \nspectrum  disorder',
#   'autism  spectrum  disorder',
#   'brain  disease',
#   'depression',
#   'developmental \ndisorders',
#   'disease',
#   'epilepsy',
#   'language devel-\nopment retardation',
#   'nc',
#   'neurodevelop-\nmental disorder',
#   'par-\nticipants',
#   'schizophrenia',
#   'viral infection'},
#  'CareEnvironment': {'Department of Paediatrics', 'Pediatric', 'Pediatrics'},
#  'Gender': {'Women', 'females', 'males', 'trans'},
#  'FamilyRelation': {'Children',
#   'child',
#   'dizygotic twins',
#   'mono-\nzygotic  twins'},
#  'AdministrativeEvent': {'RCT',
#   'case-control study',
#   'meta-analysis',
#   'multicenter meta-analysis',
#   'observational study',
#   'open-label',
#   'randomized controlled  trials',
#   'randomized controlled trials',
#   'review study',
#   'studies',
#   'twin studies'},
#  'SymptomOrSign': {'behavioral deficits',
#   'behavioral stereotypes',
#   'communication rejection',
#   'communicative',
#   'indifference',
#   'mental',
#   'social',
#   'symptom',
#   'symptoms'},
#  'Course': {'improvement', 'improves', 'increased gradually', 'repeated'},
#  'ExaminationName': {'25(OH)  D  levels',
#   'CARS',
#   'Child  Autism  Rating \nScale',
#   'Child Autism  Rating Scale',
#   'Child Autism Rating Scale',
#   'D levels',
#   'DSM-4',
#   'DSM-5',
#   'Diagnostic Statistical \nManual  of  Mental  Disorders',
#   'ICD-10',
#   'ICD-9',
#   'International Classification of \nDiseases',
#   'SMD',
#   'SRS',
#   'Social  Responsiveness  Scale',
#   'con-\ncordance  rate',
#   'concordance rate',
#   'fi-\nnal  analysis',
#   'incidence',
#   'meta-analysis',
#   'model',
#   'prevalence',
#   'scle-\nrosis',
#   'serum \n25-hydroxyvitamin  D  levels',
#   'serum 25-hydroxyvitamin  D  levels',
#   'serum vita-\nmin D levels',
#   'serum vitamin D levels',
#   'standardized mean difference',
#   'test',
#   'vitamin D levels',
#   'vitamin D3 levels'},
#  'MeasurementValue': {'0.1',
#   '203',
#   '30',
#   '31',
#   '50',
#   '60',
#   '88',
#   '90−250',
#   '95',
#   'Low',
#   'dramatically  elevated',
#   'low',
#   'reduced'},
#  'ConditionQualifier': {'unspecified'},
#  'RelationalOperator': {'less than', 'more  than', '≤', '＜', '＞'},
#  'MeasurementUnit': {'%', 'ng/ml', 'per 10,000'},
#  'Date': {'August 28, 2019', 'December 2, 2019', 'October 3, 2019'},
#  'TreatmentName': {'intervention', 'prevention', 'treatment'},
#  'GeneOrProtein': {'DNA',
#   'es-\ntrogen',
#   'estrogen receptor',
#   'estrogen receptor \ncoactivators',
#   'genes',
#   'inducible  nitric  oxide \nsynthase',
#   'neurotransmitters',
#   'neurotrophic factors',
#   'serotonin'},
#  'BodyStructure': {'brain',
#   'im',
#   'middle frontal gyrus',
#   'nerves',
#   'nervous  system',
#   'neuronal cell',
#   'placenta',
#   'uterus'},
#  'MedicationClass': {'steroid'},
#  'Expression': {'expression'},
#  'MutationType': {'abnor-\nmal'}}

# %%
import pandas as pd
df = pd.DataFrame.from_dict(ent_dict, orient='index')

# %%
df
# Out:
#                                                                     0   \
# ArticleName          Vitamin D Supplementation is Beneficial for Ch...
# Authors                                                       Zhi Chen
# Year                                                              2020
# JournalName               Clinical Psychopharmacology and Neuroscience
# Time                                                             30,36
# MedicationName                                              vitamin  D
# Age                                                          childhood
# Diagnosis                                               brain  disease
# CareEnvironment                              Department of Paediatrics
# Gender                                                           males
# FamilyRelation                                         dizygotic twins
# AdministrativeEvent                                observational study
# SymptomOrSign                                                 symptoms
# Course                                                        repeated
# ExaminationName                                                  ICD-9
# MeasurementValue                                                90−250
# ConditionQualifier                                         unspecified
# RelationalOperator                                          more  than
# MeasurementUnit                                                  ng/ml
# Date                                                   August 28, 2019
# TreatmentName                                               prevention
# GeneOrProtein                                              es-\ntrogen
# BodyStructure                                                 placenta
# MedicationClass                                                steroid
# Expression                                                  expression
# MutationType                                               abnor-\nmal
#
#                                              1   \
# ArticleName                                None
# Authors                             Xiaomei Luo
# Year                                       None
# JournalName                                None
# Time                                  September
# MedicationName                    vita-\nmin  D
# Age                                       fetal
# Diagnosis            Autism  spectrum  disorder
# CareEnvironment                      Pediatrics
# Gender                                  females
# FamilyRelation                            child
# AdministrativeEvent          case-control study
# SymptomOrSign                            social
# Course                              improvement
# ExaminationName                             SRS
# MeasurementValue                        reduced
# ConditionQualifier                         None
# RelationalOperator                            ＜
# MeasurementUnit                               %
# Date                            October 3, 2019
# TreatmentName                      intervention
# GeneOrProtein                             genes
# BodyStructure                     neuronal cell
# MedicationClass                            None
# Expression                                 None
# MutationType                               None
#
#                                                       2   \
# ArticleName                                         None
# Authors                                       Liyao Song
# Year                                                None
# JournalName                                         None
# Time                                          late 1990s
# MedicationName                                       min
# Age                                             Children
# Diagnosis            language devel-\nopment retardation
# CareEnvironment                                Pediatric
# Gender                                             trans
# FamilyRelation                                  Children
# AdministrativeEvent                        meta-analysis
# SymptomOrSign                     behavioral stereotypes
# Course                               increased gradually
# ExaminationName                        25(OH)  D  levels
# MeasurementValue                                      50
# ConditionQualifier                                  None
# RelationalOperator                                     ＞
# MeasurementUnit                               per 10,000
# Date                                    December 2, 2019
# TreatmentName                                  treatment
# GeneOrProtein        inducible  nitric  oxide \nsynthase
# BodyStructure                       middle frontal gyrus
# MedicationClass                                     None
# Expression                                          None
# MutationType                                        None
#
#                                                3   \
# ArticleName                                  None
# Authors                                   Ai Chen
# Year                                         None
# JournalName                                  None
# Time                                          ago
# MedicationName          Vitamin D Supplementation
# Age                                      children
# Diagnosis                                epilepsy
# CareEnvironment                              None
# Gender                                      Women
# FamilyRelation              mono-\nzygotic  twins
# AdministrativeEvent                    open-label
# SymptomOrSign                 behavioral deficits
# Course                                   improves
# ExaminationName      standardized mean difference
# MeasurementValue                              0.1
# ConditionQualifier                           None
# RelationalOperator                              ≤
# MeasurementUnit                              None
# Date                                         None
# TreatmentName                                None
# GeneOrProtein                   estrogen receptor
# BodyStructure                               brain
# MedicationClass                              None
# Expression                                   None
# MutationType                                 None
#
#                                                    4   \
# ArticleName                                      None
# Authors                                      Dan Wang
# Year                                             None
# JournalName                                      None
# Time                                              ;18
# MedicationName                              Vitamin D
# Age                                          18 years
# Diagnosis                    Autism Spectrum Disorder
# CareEnvironment                                  None
# Gender                                           None
# FamilyRelation                                   None
# AdministrativeEvent                               RCT
# SymptomOrSign                           communicative
# Course                                           None
# ExaminationName                    fi-\nnal  analysis
# MeasurementValue               dramatically  elevated
# ConditionQualifier                               None
# RelationalOperator                          less than
# MeasurementUnit                                  None
# Date                                             None
# TreatmentName                                    None
# GeneOrProtein        estrogen receptor \ncoactivators
# BodyStructure                                  nerves
# MedicationClass                                  None
# Expression                                       None
# MutationType                                     None
#
#                                                    5   \
# ArticleName                                      None
# Authors                                    Qing Jiang
# Year                                             None
# JournalName                                      None
# Time                                             None
# MedicationName                                      D
# Age                                              None
# Diagnosis            Pervasive Developmental Disorder
# CareEnvironment                                  None
# Gender                                           None
# FamilyRelation                                   None
# AdministrativeEvent         multicenter meta-analysis
# SymptomOrSign                            indifference
# Course                                           None
# ExaminationName                         meta-analysis
# MeasurementValue                                   95
# ConditionQualifier                               None
# RelationalOperator                               None
# MeasurementUnit                                  None
# Date                                             None
# TreatmentName                                    None
# GeneOrProtein                                     DNA
# BodyStructure                         nervous  system
# MedicationClass                                  None
# Expression                                       None
# MutationType                                     None
#
#                                                 6   \
# ArticleName                                   None
# Authors                                Lifang Zhou
# Year                                          None
# JournalName                                   None
# Time                                          None
# MedicationName                             vitamin
# Age                                           None
# Diagnosis                     Alzheimer’s  disease
# CareEnvironment                               None
# Gender                                        None
# FamilyRelation                                None
# AdministrativeEvent  randomized controlled  trials
# SymptomOrSign                              symptom
# Course                                        None
# ExaminationName      Social  Responsiveness  Scale
# MeasurementValue                               low
# ConditionQualifier                            None
# RelationalOperator                            None
# MeasurementUnit                               None
# Date                                          None
# TreatmentName                                 None
# GeneOrProtein                 neurotrophic factors
# BodyStructure                               uterus
# MedicationClass                               None
# Expression                                    None
# MutationType                                  None
#
#                                                7                        8   \
# ArticleName                                  None                     None
# Authors                                      None                     None
# Year                                         None                     None
# JournalName                                  None                     None
# Time                                         None                     None
# MedicationName          1,25-dihydroxy vitamin D3                vitamin D
# Age                                          None                     None
# Diagnosis                                     ASD                   autism
# CareEnvironment                              None                     None
# Gender                                       None                     None
# FamilyRelation                               None                     None
# AdministrativeEvent  randomized controlled trials             review study
# SymptomOrSign                              mental  communication rejection
# Course                                       None                     None
# ExaminationName         serum vita-\nmin D levels         vitamin D levels
# MeasurementValue                               60                       31
# ConditionQualifier                           None                     None
# RelationalOperator                           None                     None
# MeasurementUnit                              None                     None
# Date                                         None                     None
# TreatmentName                                None                     None
# GeneOrProtein                   neurotransmitters                serotonin
# BodyStructure                                  im                     None
# MedicationClass                              None                     None
# Expression                                   None                     None
# MutationType                                 None                     None
#
#                                              9   ...                      21  \
# ArticleName                                None  ...                    None
# Authors                                    None  ...                    None
# Year                                       None  ...                    None
# JournalName                                None  ...                    None
# Time                                       None  ...                    None
# MedicationName                       Vitamin  D  ...                    None
# Age                                        None  ...                    None
# Diagnosis                                    af  ...                    ASDs
# CareEnvironment                            None  ...                    None
# Gender                                     None  ...                    None
# FamilyRelation                             None  ...                    None
# AdministrativeEvent                twin studies  ...                    None
# SymptomOrSign                              None  ...                    None
# Course                                     None  ...                    None
# ExaminationName      Child Autism  Rating Scale  ...  serum vitamin D levels
# MeasurementValue                            203  ...                    None
# ConditionQualifier                         None  ...                    None
# RelationalOperator                         None  ...                    None
# MeasurementUnit                            None  ...                    None
# Date                                       None  ...                    None
# TreatmentName                              None  ...                    None
# GeneOrProtein                              None  ...                    None
# BodyStructure                              None  ...                    None
# MedicationClass                            None  ...                    None
# Expression                                 None  ...                    None
# MutationType                               None  ...                    None
#
#                                              22                   23  \
# ArticleName                                None                 None
# Authors                                    None                 None
# Year                                       None                 None
# JournalName                                None                 None
# Time                                       None                 None
# MedicationName                             None                 None
# Age                                        None                 None
# Diagnosis            Autism \nSpectrum Disorder  Parkinson’s disease
# CareEnvironment                            None                 None
# Gender                                     None                 None
# FamilyRelation                             None                 None
# AdministrativeEvent                        None                 None
# SymptomOrSign                              None                 None
# Course                                     None                 None
# ExaminationName                           model                  SMD
# MeasurementValue                           None                 None
# ConditionQualifier                         None                 None
# RelationalOperator                         None                 None
# MeasurementUnit                            None                 None
# Date                                       None                 None
# TreatmentName                              None                 None
# GeneOrProtein                              None                 None
# BodyStructure                              None                 None
# MedicationClass                            None                 None
# Expression                                 None                 None
# MutationType                               None                 None
#
#                                                        24    25  \
# ArticleName                                          None  None
# Authors                                              None  None
# Year                                                 None  None
# JournalName                                          None  None
# Time                                                 None  None
# MedicationName                                       None  None
# Age                                                  None  None
# Diagnosis                                            None  None
# CareEnvironment                                      None  None
# Gender                                               None  None
# FamilyRelation                                       None  None
# AdministrativeEvent                                  None  None
# SymptomOrSign                                        None  None
# Course                                               None  None
# ExaminationName      serum \n25-hydroxyvitamin  D  levels  CARS
# MeasurementValue                                     None  None
# ConditionQualifier                                   None  None
# RelationalOperator                                   None  None
# MeasurementUnit                                      None  None
# Date                                                 None  None
# TreatmentName                                        None  None
# GeneOrProtein                                        None  None
# BodyStructure                                        None  None
# MedicationClass                                      None  None
# Expression                                           None  None
# MutationType                                         None  None
#
#                                                              26  \
# ArticleName                                                None
# Authors                                                    None
# Year                                                       None
# JournalName                                                None
# Time                                                       None
# MedicationName                                             None
# Age                                                        None
# Diagnosis                                                  None
# CareEnvironment                                            None
# Gender                                                     None
# FamilyRelation                                             None
# AdministrativeEvent                                        None
# SymptomOrSign                                              None
# Course                                                     None
# ExaminationName      International Classification of \nDiseases
# MeasurementValue                                           None
# ConditionQualifier                                         None
# RelationalOperator                                         None
# MeasurementUnit                                            None
# Date                                                       None
# TreatmentName                                              None
# GeneOrProtein                                              None
# BodyStructure                                              None
# MedicationClass                                            None
# Expression                                                 None
# MutationType                                               None
#
#                                    27    28  \
# ArticleName                      None  None
# Authors                          None  None
# Year                             None  None
# JournalName                      None  None
# Time                             None  None
# MedicationName                   None  None
# Age                              None  None
# Diagnosis                        None  None
# CareEnvironment                  None  None
# Gender                           None  None
# FamilyRelation                   None  None
# AdministrativeEvent              None  None
# SymptomOrSign                    None  None
# Course                           None  None
# ExaminationName      concordance rate  test
# MeasurementValue                 None  None
# ConditionQualifier               None  None
# RelationalOperator               None  None
# MeasurementUnit                  None  None
# Date                             None  None
# TreatmentName                    None  None
# GeneOrProtein                    None  None
# BodyStructure                    None  None
# MedicationClass                  None  None
# Expression                       None  None
# MutationType                     None  None
#
#                                                      29          30
# ArticleName                                        None        None
# Authors                                            None        None
# Year                                               None        None
# JournalName                                        None        None
# Time                                               None        None
# MedicationName                                     None        None
# Age                                                None        None
# Diagnosis                                          None        None
# CareEnvironment                                    None        None
# Gender                                             None        None
# FamilyRelation                                     None        None
# AdministrativeEvent                                None        None
# SymptomOrSign                                      None        None
# Course                                             None        None
# ExaminationName      serum 25-hydroxyvitamin  D  levels  prevalence
# MeasurementValue                                   None        None
# ConditionQualifier                                 None        None
# RelationalOperator                                 None        None
# MeasurementUnit                                    None        None
# Date                                               None        None
# TreatmentName                                      None        None
# GeneOrProtein                                      None        None
# BodyStructure                                      None        None
# MedicationClass                                    None        None
# Expression                                         None        None
# MutationType                                       None        None
#
# [26 rows x 31 columns]

# %%
### Saving the result as a CSV file. The name of the file corresponds to the name of the pdf file.
output_file_name = pdf_file_path.split("/")[2].split(".")[0]
output_file_path = "./outputs/" + output_file_name + ".csv"
df.to_csv(output_file_path)

# %%
# Some testing texts

documents = ["""Autism is a neurodevelopmental disorder characterized by impairment in three core symptom domains:
                socialization, communication, and repetitive/stereotyped behaviours. Other associated symptom
                domains are also affected including impulsivity/aggression, self-injury, anxiety, and mood lability.
                Divalproex has been shown to have efficacy in treating epilepsy, bipolar disorder, mood lability, and
                impulsive aggression. The present study evaluated the use of divalproex in the treatment of repetitive,
                compulsive-like symptoms of autism spectrum disorder (ASD). Thirteen individuals with ASD participated
                in an 8-wk, double-blind, placebo-controlled trial of divalproex sodium vs. placebo. There was a
                significant group difference on improvement in repetitive behaviours as measured by the Children’s
                Yale–Brown Obsessive Compulsive Scale (C-YBOCS) (p=0.037) and a large effect size (d=1.616). This
                study provides preliminary support for the use of divalproex in treating repetitive behaviours in ASD.
                Further research is needed to evaluate the specificity and mechanism of action of these findings."""]


document1 = ["""
                Patients were recruited and screened for the presence
                of ASDs at the Seaver and New York Autism Center
                of Excellence. Twenty-five subjects were screened.
                Thirteen subjects were randomized, had at least one
                post-treatment outcome measure, and were included
                in the intent-to-treat (ITT) group. One subject dropped
                out in week 5 due to lack of efficacy (on medication)
                and 12 subjects completed the trial.
                The average age of subjects was 9.5 yr (12 were
                child/adolescents with an age range 5–17 yr, and one
                was an adult, age 40 yr). Eight of the subjects were
                Caucasian, two were African American, two were
                Asian and one was Hispanic. Baseline assessments
                included comprehensive psychiatric, diagnostic,
                psychological, and medical evaluations. Diagnoses
                were established using DSM-IV criteria, Autism
                Diagnostic Interview – Revised (ADI-R), and Autism
                Diagnostic Observation Schedule (ADOS). Ten of
                the participants were diagnosed with autistic disorder,
                two were diagnosed with Asperger’s disorder and
                one was diagnosed with pervasive developmental
                disotherwise specified (PDD-NOS).
                Psychological testing included measures of cognitive
                functioning and adaptive behaviour. The sample
                represents the moderate to low functioning end of the
                autism spectrum. IQ scores for the majority of participants
                were in the mild to moderate mental retardation
                range, with a mean IQ score of 60 (range=30–104).
                Scores on the Vineland Adaptive Behaviour Scale fell
                in the moderately to severely impaired range of functioning
                (mean=44, standard deviation=22).
                Inclusion criteria for the study included subjects
                meeting DSM-IV and ADI-R criteria for an ASD
                and scoring as moderately ill on Clinical Global
                Impression Scale for Autistic Disorder (CGI-AD)
                rating. Patients were not selected on the basis of levels
                of repetitive or aggressive behaviours on study
                measures. Exclusion criteria included medical illnesses
                (with the exception of stable seizure disorder), past
                history of psychotic disorders, and recent or current
                use of divalproex, terfenadine (Seldane), or astemizole
                (Hismanal). Subjects using any psychoactive medication
                were allowed to participate in the trial only if
                the dose remained stable for at least 3 months prior to
                and during the trial. Only one participant was on a
                stable dose of risperidone prior to the study and continued
                throughout the 8 wk of the study. No other
                participant was on concomitant medications. This
                study was approved by the Mount Sinai Institutional
                Review Board. All participants provided informed
                consent prior to participation.
"""]


documents2 = ["""
Abstract
Background: Suboptimal physical activity levels and tolerance, poor motor skills and poor physical health are
demonstrated in children with Autism Spectrum Disorder (ASD). We speculate that social interaction and
communication deficits in children with ASD are two major factors that hinder these children from actively
participating in group physical activities. While previous studies have demonstrated that exercise intervention improves
motor skills and behavioral outcomes in children with ASD, these programs tend to focus only on a single sport, which
may not cater to the interests of different children with ASD. In this protocol, a game-based exercise training program
designed by a multi-disciplinary team (pediatrics, physical education and psychology) will be implemented by frontline
healthcare providers trained following the train-the-trainer (TTT) model and subjected to validation.
Method: Using a randomized controlled trial design, the effectiveness of the game-based exercise program will be
examined for 112 young children with ASD. These children were randomly assigned to two groups, which will be
tested and trained in either one of the two arms of the waitlist conditions (control and intervention). The assessment
of physical and psychological traits will be conducted at baseline (pre-test), at 16-weeks (post-treatment) and at 32-
weeks (follow-up) of the program.
Discussion: Most of the interventions designed for ASD children target either their psychological traits or physical
conditions, without bridging the two states. With the recognition of bidirectional relations between mental and
physical health, the present game-based exercise program which includes multiple level of difficulties was developed
to equip ASD children with the necessary skills for engaging in sustainable team sports or even professional sport
training. The program, if effective, will provide an entertaining and engaging training for whole-person development
among children with ASD.
Trial registration: This study is registered with the Chinese Clinical Trial Registry (ChiCTR-IOR-17011898). Registered 6th
July 2017.Abstract
Background: Suboptimal physical activity levels and tolerance, poor motor skills and poor physical health are
demonstrated in children with Autism Spectrum Disorder (ASD). We speculate that social interaction and
communication deficits in children with ASD are two major factors that hinder these children from actively
participating in group physical activities. While previous studies have demonstrated that exercise intervention improves
motor skills and behavioral outcomes in children with ASD, these programs tend to focus only on a single sport, which
may not cater to the interests of different children with ASD. In this protocol, a game-based exercise training program
designed by a multi-disciplinary team (pediatrics, physical education and psychology) will be implemented by frontline
healthcare providers trained following the train-the-trainer (TTT) model and subjected to validation.
Method: Using a randomized controlled trial design, the effectiveness of the game-based exercise program will be
examined for 112 young children with ASD. These children were randomly assigned to two groups, which will be
tested and trained in either one of the two arms of the waitlist conditions (control and intervention). The assessment
of physical and psychological traits will be conducted at baseline (pre-test), at 16-weeks (post-treatment) and at 32-
weeks (follow-up) of the program.
Discussion: Most of the interventions designed for ASD children target either their psychological traits or physical
conditions, without bridging the two states. With the recognition of bidirectional relations between mental and
physical health, the present game-based exercise program which includes multiple level of difficulties was developed
to equip ASD children with the necessary skills for engaging in sustainable team sports or even professional sport
training. The program, if effective, will provide an entertaining and engaging training for whole-person development
among children with ASD.
Trial registration: This study is registered with the Chinese Clinical Trial Registry (ChiCTR-IOR-17011898). Registered 6th
July 2017.

"""    
]
